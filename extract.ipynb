# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read JSON of pipeline data

# %%
df = pd.read_json('./info from WorkStep/candidate_funnel_2022_08.json')

# %%
df
# Out:
#        company_id position_role_type  position_id                      date  \
# 0           75621         PRODUCTION    134935318 2022-08-04 00:00:00+00:00
# 1           75621         PRODUCTION   3102362893 2022-08-04 00:00:00+00:00
# 2           75621         PRODUCTION   3102362893 2022-08-15 00:00:00+00:00
# 3           75621         PRODUCTION   7797193831 2022-08-02 00:00:00+00:00
# 4           75621         PRODUCTION   7797193831 2022-08-12 00:00:00+00:00
# ...           ...                ...          ...                       ...
# 40930       18738          WAREHOUSE    200792455 2022-08-11 00:00:00+00:00
# 40931       18738          WAREHOUSE    200792455 2022-08-12 00:00:00+00:00
# 40932       18738          WAREHOUSE    200792455 2022-08-13 00:00:00+00:00
# 40933       18738          WAREHOUSE    200792455 2022-08-14 00:00:00+00:00
# 40934       18738          WAREHOUSE    200792455 2022-08-15 00:00:00+00:00
#
# ...
